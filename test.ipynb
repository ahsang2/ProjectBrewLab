# %%
# Force reload modules to get latest changes
import importlib
import sys
if 'merge_data' in sys.modules:
    importlib.reload(sys.modules['merge_data'])

# %%
# Define your desired date range
start = datetime(2025, 8, 1)
end = datetime(2025, 8, 3)

# Run merge and view the final dataframe
final_df = merge_data(start, end)
final_df.head()

# %%
# Setup
from datetime import datetime
import pandas as pd
from dotenv import load_dotenv
load_dotenv()

from merge_data import merge_data

# %%
final_df

# %%
# Optional: inspect columns and basic stats
print(final_df.columns.tolist())
final_df.describe(include='all')

# %%
# Debug: Check the actual content of line 19 in merge_data.py
with open('merge_data.py', 'r') as f:
    lines = f.readlines()
    print(f"Line 19: {lines[18].strip()}")  # Line 19 is index 18

# %%
print(final_df.columns)
